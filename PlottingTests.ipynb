# %%
import pandas as pd

# %%
df = pd.read_json("muacirclejerk.json")

# %%
sorted_scores = df.sort_values(by='score', ascending=False)

# %%
sorted_scores.head()
# Out:
#     comments  gilded  score                                              title
# 38       105       0   1693  My chic, minimalist vanity. I went with a warm...
# 0         17       0   1651                    Reminder about our STDS unitive
# 95       203       0   1489        Omg Kat von D's new palette is sooo pretty!
# 16       182       1   1283  PSA: Please Stop Abusing Your Highlighter! I c...
# 85        28       0   1048  Teal vanities are for PORES. Look at the PLATI...

# %%
sorted_scores["score"].head()
# Out:
# 38    1693
# 0     1651
# 95    1489
# 16    1283
# 85    1048
# Name: score, dtype: int64

# %%
sorted_scores.sort_index()
# Out:
#     comments  gilded  score                                              title
# 0         17       0   1651                    Reminder about our STDS unitive
# 1         44       0    243                MEME THREAD MEME THREAD MEME THREAD
# 2         25       0    908  None of you pores could come CLOSE to my skinc...
# 3         27       0    571   Impressed with my eye lewk? Who's impressed? 🤩✨📲
# 4         44       0    295                                         Boyglam...
# 5          5       0     17        mEN OF rEDDIT, TIME TO COMPLAIN ABOUT WOMEN
# 6          2       0     98                                         ~BoY gLaM~
# 7          7       0     21  My UNBIASED review of a pallette from a compan...
# 8         13       0    152  Watch until the end to find out what makeup ar...
# 9         10       0    109                Tips for vanity for my girlfriend??
# 10         1       0     71        FINALLY getting the recognition I deserve 👑
# 11         5       0     92                     does kat von d have a p.o. box
# 12         7       0     75                                            Boyglam
# 13         5       0     30    I aM a MaK3-UP aRtI$t. Th1s I$ mY sCoRpI0 £eWk.
# 14         2       0     22  My eye makeup is 👅 proof. Don't ask it's a sex...
# 15         1       0      5        trying out a new everyday LEWK CW welcome 😘
# 16       182       1   1283  PSA: Please Stop Abusing Your Highlighter! I c...
# 17         3       0     29                                    Boyglam Queenz!
# 18         0       0     19                    It's a SECKS thing, sweatpie ~~
# 19         1       0      5  Colourpop victimizes pale princesses with thei...
# 20         5       0      7                I think I have the best boyfie ever
# 21         4       0     45  Really feeling this seasonal nail art. Sorry a...
# 22         9       0     22                  🤑 u pOrEs cAN't geT ON mY LeVeL 🤑
# 23         3       0     28                                             Orange
# 24        10       0    358  What’s that about filters you said? 😂 I can ta...
# 25        20       0    474                          All my current pans 💁🏼‍♀️
# 26        29       0    127            Learning how to contour, CCNFW sweaties
# 27         3       0      9                        I'm like so low maintenance
# 28        26       0     67  B+A Daytime Makeup Lewk. Updoots to the left. ...
# 29        34       0    760                    Contour with autumn lippie lewk
# ..       ...     ...    ...                                                ...
# 70        20       0    628                                Soft glam pink look
# 71         4       0     50                               My candy corn look 😍
# 72        11       0    226                      Working on my blending skills
# 73         7       0    107                I tried a butterfly look. Thoughts?
# 74         6       0     83  Am such a pale princess talcum powder is my fo...
# 75        11       0    155                        Thought this fits well here
# 76        13       0     95              My highlight has never looked better!
# 77         0       0      9                            LOL funny how pail I am
# 78        13       0     52                      Working on my blending skills
# 79         3       0     34                Channeling my inner little mermaid!
# 80         2       0     42  holy grail from l’uxitanye panned 😭 should I r...
# 81         9       0     53                        no filter c👏c👏n👏w👏 porez!!!
# 82         3       0     46                    My favorite type of makeup look
# 83         7       0    118                                       Red lippie 💋
# 84         2       0     27                              Simple everyday look!
# 85        28       0   1048  Teal vanities are for PORES. Look at the PLATI...
# 86        15       0     40                       Pallett for pail princess???
# 87         9       0    239                                         Face Mask!
# 88         6       0     74             Blue makes me feel like a badass bitxh
# 89        11       1    242                   One teal Vanity to rule them all
# 90         8       0     55                             Babydoll look CCNFW 👶🏻
# 91        20       0     83  SRS: lurking and contributing to this sub has ...
# 92        74       0    249  /r/muacirclejerk/ is using the photos you post...
# 93        11       0    146  [TRUE PAN for you pores] Another day, another ...
# 94        15       0    111  Did a look with the pat mcgrath mothership v p...
# 95       203       0   1489        Omg Kat von D's new palette is sooo pretty!
# 96         5       0    182                                   Earthy colors <3
# 97         6       0    103                  Today’s work look ft. bat decor 🦇
# 98         4       0     83    Here’s a CLOSE UP for you PORES with bad vision
# 99         5       0     77  Journal Entry #123 Post-Infection: Finally, I ...
#
# [100 rows x 4 columns]

# %%
sorted_scores[["score", "gilded"]].plot(kind = 'bar')

# %%
sorted_scores["score"].plot(kind = 'hist', bins = 10)

# %%
sorted_scores[0:5].plot(kind='barh',x='title',y='score')

# %%
allscore = sorted_scores["score"].sum()
topscore = sorted_scores["score"][0]
piechart = pd.DataFrame({
    'Score' : [allscore, topscore]},
    index=['alls','tops'])

piechart
# Out:
#       Score
# alls  20772
# tops   1651

# %%
piechart.plot(kind='pie',y='Score')

# %%
sorted_scores[0:5].plot(kind='barh',x='title',y='score', subplots=True)

# %%
testnew = pd.DataFrame({
    'comments' : sorted_scores["comments"],
    'score' : sorted_scores["score"]})

testnew[0:5].plot(kind='barh')
