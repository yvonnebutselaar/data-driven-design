# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Y = gender

# %%
df = pd.read_csv('ex3data.csv')
df
# Out:
#     id  gender  instagram_followers  linkedin_con  texts_yesterday  \
# 0    1    male                  0.0         642.0             47.0
# 1    2  female                155.0         157.0            150.0
# 2    3  female                169.0         119.0             20.0
# 3    4    male                  NaN         150.0            100.0
# 4    5    male                 25.0         120.0            420.0
# 5    6    male                  0.0         187.0             20.0
# 6    7  female                  NaN           NaN              NaN
# 7    8  female                203.0         203.0            143.0
# 8    9  female                  NaN           NaN              NaN
# 9   10    male                126.0         119.0             85.0
# 10  11    male                  0.0         171.0            150.0
# 11  12    male                184.0        1000.0              NaN
# 12  13  female                131.0         399.0             27.0
# ...

# %%
gender = pd.DataFrame(df['gender'].value_counts())
gender
# Out:
#         gender
# male        15
# female      11

# %%
sns.countplot(x=df['gender'], palette="Pastel1")

# %%
gender = pd.DataFrame(df['gender'].value_counts(normalize=True))
gender = gender * 100
gender
# Out:
#            gender
# male    57.692308
# female  42.307692

# %%
dfa = pd.crosstab(df.gender, df.os_phone, normalize='index')
dfa = dfa * 100
dfa
# Out:
# os_phone  Android   iOS
# gender
# female       50.0  50.0
# male         60.0  40.0

# %%
sns.catplot(kind="count", x="gender", hue="os_phone", data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-7adc8c78c463> in <module>()
# ----> 1 sns.catplot(kind="bar", x="gender", hue="os_phone", data=df)
#
# AttributeError: module 'seaborn' has no attribute 'catplot'
