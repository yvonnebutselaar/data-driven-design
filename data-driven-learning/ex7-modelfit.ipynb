# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr 
import sklearn as sk
import math
from sklearn.linear_model import LinearRegression #remember, this is linear regression model from sk-learn
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('funda-amsterdam.csv')
df.head(3)
# Out:
#    Unnamed: 0                    address  area  bedrooms postal_code  \
# 0           0  Knollendamstraat 4 III/IV   108         2     1013 TN
# 1           1        Moerdijkstraat 47 1    47         1     1079 XM
# 2           2          Zeeburgerdijk 349   116         2     1095 AD
#
#   posting_date   price property_type  rooms  sale_date  \
# 0     4-6-2016  510000     apartment      3  23-6-2016
# 1    22-6-2016  215000     apartment      2   5-7-2016
# 2     9-6-2016  325000     apartment      3   8-7-2016
#
#                                                  url  year_built
# 0  http://www.funda.nl/koop/verkocht/amsterdam/ap...        1906
# 1  http://www.funda.nl/koop/verkocht/amsterdam/ap...        1938
# 2  http://www.funda.nl/koop/verkocht/amsterdam/ap...        2003

# %% [markdown]
# ### Quantitative Variables
# The variables I'm going to work with are price, area and rooms.
# After making the first plot some houses were sold for 0 euros. Let's remove those.

# %%
sdf = df[['area', 'rooms', 'price']]
sdf.head(5)
# Out:
#    area  rooms   price
# 0   108      3  510000
# 1    47      2  215000
# 2   116      3  325000
# 3    58      3  315000
# 4    63      3  200000

# %%
sdf = sdf.loc[(sdf['price'] > 10000) & (sdf['rooms'] > 0) & (sdf['area'] > 10)]

# %% [markdown]
# Had to use .loc since the normal notation didn't work. Added the rest of the categories (rooms & area) to see if & would work

# %%
sns.pairplot(sdf)

# %%
sns.scatterplot(x="price", y="area", data=sdf)

# %% [markdown]
# The relationship between the price and area is linear.

# %%
sns.regplot(x="price", y="area", data=sdf)

# %%
pearsonr(sdf['price'], sdf['area'])
# Out:
# (0.7250807666953685, 0.0)

# %% [markdown]
# The price and area are highly correlated since the r > 0.6 -
# The correlation is significant.

# %%
sns.regplot(x="area", y="price", data=sdf)

# %% [markdown]
# ### SK-learn, linear regression
# I'm not sure what model to pick, both seem to work as graphs.
# However, the second one looks better, so we'll go with area as X
#
# The formula is
# $ b0 + b1 X + e $
#
# Our X is area
# Our Y is price
#
# We will calculate the b0 and b1 with sk-learn

# %%
from sklearn.linear_model import LinearRegression

x = sdf[['area']] 
y = sdf['price']
lm = LinearRegression()
lm.fit(x, y)

b0 = lm.coef_[0]
b1 = lm.intercept_

# %% [markdown]
# Our b0 is 3498.8143600771396 ;
# Our b1 is 27983.929867592116
#
# ### Predictions
# Putting X = 70, we can fill in our predict function:

# %%
lm.predict(70)
# Out:
# array([272900.93507299])

# %%
sdf['price_prediction'] = lm.predict(x)
sdf.head(10)
# Out:
#    area  rooms   price  price_prediction
# 0   108      3  510000     405855.880756
# 1    47      2  215000     192428.204791
# 2   116      3  325000     433846.395637
# 3    58      3  315000     230915.162752
# 4    63      3  200000     248409.234552
# 5   125      3  515000     465335.724877
# 6    64      4  200000     251908.048913
# 7   155      5  599000     570300.155680
# 8    85      3  249000     325383.150474
# 9    67      3  300000     262404.491993

# %%
add = 'Slichtenhorststraat 10'
aa = df[df['address'] == add]
aa
# Out:
#     Unnamed: 0                 address  area  bedrooms postal_code  \
# 21          21  Slichtenhorststraat 10   114         3     1107 VH
#
#    posting_date   price property_type  rooms sale_date  \
# 21    18-9-2015  234500         house      4  3-5-2016
#
#                                                   url  year_built
# 21  http://www.funda.nl/koop/verkocht/amsterdam/hu...        1983

# %% [markdown]
# We now know that the area of SLichtenhorststraat is 114. putting this number in our predict function...

# %%
lm.predict(114)
# Out:
# array([426848.76691639])

# %% [markdown]
# Gives us a price point of 426848

# %% [markdown]
# ## the E
#
# But the property was sold for €234500 instead of the predicted €426848
# This means our E = -192348

# %% [markdown]
# # Model Evaluation (Start ex. 7)

# %% [markdown]
# We're starting off by grabbing our price predictions from last exercise

# %%
sdf['price_prediction'] = lm.predict(x)
sdf.head(10)
# Out:
#    area  rooms   price  price_prediction
# 0   108      3  510000     405855.880756
# 1    47      2  215000     192428.204791
# 2   116      3  325000     433846.395637
# 3    58      3  315000     230915.162752
# 4    63      3  200000     248409.234552
# 5   125      3  515000     465335.724877
# 6    64      4  200000     251908.048913
# 7   155      5  599000     570300.155680
# 8    85      3  249000     325383.150474
# 9    67      3  300000     262404.491993

# %% [markdown]
# Now, we want no numbers behind the comma, so we're trimming sdf[price_prediction]

# %%
sdf['error'] = sdf['price'] - sdf['price_prediction'].astype(int)

# %%
sdf
# Out:
#        area  rooms   price  price_prediction   error
# 0       108      3  510000     405855.880756  104145
# 1        47      2  215000     192428.204791   22572
# 2       116      3  325000     433846.395637 -108846
# 3        58      3  315000     230915.162752   84085
# 4        63      3  200000     248409.234552  -48409
# 5       125      3  515000     465335.724877   49665
# 6        64      4  200000     251908.048913  -51908
# 7       155      5  599000     570300.155680   28700
# 8        85      3  249000     325383.150474  -76383
# 9        67      3  300000     262404.491993   37596
# 10      100      4  445000     377865.365875   67135
# 11       43      2  179000     178432.947351     568
# 12       49      3  200000     199425.833511     575
# 13       65      3  339000     255406.863273   83594
# 14       46      3  200000     188929.390431   11071
# 15       74      3  375000     286896.192513   88104
# 16      130      4  665000     482829.796678  182171
# 17       58      3  289000     230915.162752   58085
# 18       66      4  300000     258905.677633   41095
# 19       59      4  225000     234413.977112   -9413
# 20       70      2  125000     272900.935073 -147900
# 21      114      4  234500     426848.766916 -192348
# 22      112      4  219000     419851.138196 -200851
# 23       90      3  535000     342877.222275  192123
# 24      147      7  295000     542309.640799 -247309
# 25      107      4  260000     402357.066396 -142357
# 26       24      1  170000     111955.474509   58045
# 27      127      4  825000     472333.353597  352667
# 28      112      3  950000     419851.138196  530149
# 29      112      3  825000     419851.138196  405149
# ...     ...    ...     ...               ...     ...
# 11413   170      7  595000     622782.371081  -27782
# 11414    72      4  325000     279898.563793   45102
# 11415    60      2  195000     237912.791472  -42912
# 11416    45      3  219000     185430.576071   33570
# 11417    48      2  209000     195927.019151   13073
# 11418    57      2  192500     227416.348392  -34916
# 11419    95      4  249000     360371.294075 -111371
# 11420    83      3  235000     318385.521754  -83385
# 11421   140      7  595000     517817.940278   77183
# 11422    70      3  132000     272900.935073 -140900
# 11423    89      3  189000     339378.407914 -150378
# 11424    85      4  325000     325383.150474    -383
# 11425    96      3  489500     363870.108435  125630
# 11426    80      3  189000     307889.078674 -118889
# 11427    40      1  140000     167936.504271  -27936
# 11428    51      3  169000     206423.462232  -37423
# 11429   100      2  479000     377865.365875  101135
# 11430   132      4  359500     489827.425398 -130327
# 11431    76      4  185000     293893.821233 -108893
# 11432    62      3  299000     244910.420192   54090
# 11433   100      4  235000     377865.365875 -142865
# 11434    74      2  525000     286896.192513  238104
# 11435    76      3  185000     293893.821233 -108893
# 11436    54      2  225000     216919.905312    8081
# 11437    51      3  225000     206423.462232   18577
# 11438   113      5  599000     423349.952556  175651
# 11439    88      3  399000     335879.593554   63121
# 11440    77      4  399000     297392.635594  101608
# 11441    90      4  259000     342877.222275  -83877
# 11442    54      3  165000     216919.905312  -51919
#
# [11081 rows x 5 columns]

# %% [markdown]
# Now to plot (Y, Y') & X, sdf['error']

# %%
# (Y, Y')
sns.scatterplot(x="price", y="price_prediction", data=sdf)

# %%
# (X, e)
sns.scatterplot(x="area", y="error", data=sdf, color="red")

# %% [markdown]
# ## Calculating R²

# %%
r2_score(sdf['price'], sdf['price_prediction'])
# Out:
# 0.5257421182315434

# %% [markdown]
# ## Calculating RMSE

# %% [markdown]
# Step 1) Square all residuals; Step 2) Calculate the mean; Step 3) Divide through amount of numbers; Step 4) take the root of this

# %%
RMSE = sdf['error'] ** 2
a = RMSE.sum() / 11442 
b = math.sqrt(a)
# The RMSE = 1103
#or.. with the notebook..
b
# Out:
# 116140.21524166458

# %%
math.sqrt(mean_squared_error(sdf['area'], sdf['error']))
# Out:
# 118016.91170922763

# %%
math.sqrt(mean_squared_error(sdf['price'], sdf['price_prediction']))
# Out:
# 118016.8786153502

# %% [markdown]
# ## Conclusions

# %% [markdown]
# The bigger the house's area, the worse the predictions.
